# %%
import pandas as pd
from StringProcessing import preprocessInput

# %% [markdown]
# # Target values

# %%
latin_2_common = preprocessInput('../data/vocabulary_LB_to_common_names_09082022.tsv', reflexive=True, balance= False, noise = 0.0, sep='\t', maxlen = 100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1299 entries, 0 to 1298
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lb        1299 non-null   object
#  1   mappings  1299 non-null   object
# dtypes: object(2)
# memory usage: 20.4+ KB
# None
# Processing file: ----------------------------------------
# Renaming colums:
# 	Current names: Index(['lb', 'mappings'], dtype='object')
# 	New names: Index(['x', 'y'], dtype='object')
# Dropping row with empty cells:
# 	Dropped 0 rows with empty cells.
# 	Cleaning string sequences.
# 	Uppercasing string sequences.
# Dropping sequences longer than the maxlen of 100:
# 	Dropped 0 that exceeded the maximum sequence length.
# Dropping duplicate sequences:
# 	Dropped 321 duplicate sequences.
# Done processing: ---------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2277 entries, 0 to 2276
# Data columns (total 2 columns):
# ...

# %%
latin_2_common["y"].apply(len).describe()
# Out:
# count    2277.000000
# mean       14.424242
# std         4.576924
# min         2.000000
# 25%        11.000000
# 50%        15.000000
# 75%        18.000000
# max        29.000000
# Name: y, dtype: float64

# %%
latin_2_common["y"].value_counts(ascending=True)
# Out:
# COMMON RUSH             1
# LOVAGE                  1
# STEVIA                  1
# MADONNA LILY            1
# WHITE LILY              1
#                        ..
# TRIBULUS TERRESTRIS    13
# VERBASCUM THAPSUS      13
# INULA HELENIUM         13
# ARCTIUM LAPPA          14
# BETA VULGARIS          18
# Name: y, Length: 1234, dtype: int64

# %% [markdown]
# ## Add some Unmapped gsrs positive pairs
# Data from 4) positive-unmapped-pairs-gsrs-name-to-common-name.tsv -- POSITIVE unmapped pairs G-SRS to Latin binomial common name

# %%
common_2_latin = preprocessInput('../data/positive-unmapped-pairs-common-name-or-latin-binomial-copies.tsv', reflexive=True, balance= False, noise = 0.0, sep='\t', maxlen = 100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   common_name     728 non-null    object
#  1   latin_binomial  728 non-null    object
# dtypes: object(2)
# memory usage: 11.5+ KB
# None
# Processing file: ----------------------------------------
# Renaming colums:
# 	Current names: Index(['common_name', 'latin_binomial'], dtype='object')
# 	New names: Index(['x', 'y'], dtype='object')
# Dropping row with empty cells:
# 	Dropped 0 rows with empty cells.
# 	Cleaning string sequences.
# 	Uppercasing string sequences.
# Dropping sequences longer than the maxlen of 100:
# 	Dropped 0 that exceeded the maximum sequence length.
# Dropping duplicate sequences:
# 	Dropped 728 duplicate sequences.
# Done processing: ---------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# ...

# %%
common_2_latin["y"].apply(len).describe()
# Out:
# count    728.000000
# mean      17.193681
# std        3.765055
# min        5.000000
# 25%       15.000000
# 50%       17.000000
# 75%       19.000000
# max       30.000000
# Name: y, dtype: float64

# %%
common_2_latin["y"].value_counts(ascending=True)
# Out:
# PRUNUS SPINOSA          1
# GALIUM APARINE          1
# VACCINIUM MYRSINITES    1
# AFRAMOMUM MELEGUETA     1
# PLANTAGO MAJOR          1
#                        ..
# HORNY GOAT WEED         2
# ELDERBERRY              2
# CORDYCEPS               2
# GARCINIA                2
# LICORICE                4
# Name: y, Length: 698, dtype: int64

# %% [markdown]
# ## Add some positive unmmaped common and latin-binomial pairs
# Data from 5) positive-unmapped-pairs-common-name-or-latin-binomial-copies.tsv -- POSITIVE unmapped pairs common-name to common name, common name to Latin binomial and vice versa, Latin binomial to Latin binomial

# %%
gsrs_2_common = preprocessInput('../data/positive-unmapped-pairs-gsrs-name-to-common-name.tsv', reflexive=True, balance= False, noise = 0.0, sep='\t', maxlen = 100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10838 entries, 0 to 10837
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         10838 non-null  object
#  1   common_name  199 non-null    object
# dtypes: object(2)
# memory usage: 169.5+ KB
# None
# Processing file: ----------------------------------------
# Renaming colums:
# 	Current names: Index(['name', 'common_name'], dtype='object')
# 	New names: Index(['x', 'y'], dtype='object')
# Dropping row with empty cells:
# 	Dropped 10639 rows with empty cells.
# 	Cleaning string sequences.
# 	Uppercasing string sequences.
# Dropping sequences longer than the maxlen of 100:
# 	Dropped 0 that exceeded the maximum sequence length.
# Dropping duplicate sequences:
# 	Dropped 0 duplicate sequences.
# Done processing: ---------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# ...

# %%
gsrs_2_common["y"].apply(len).describe()
# Out:
# count    398.000000
# mean      15.027638
# std        8.362489
# min        5.000000
# 25%        8.000000
# 50%       12.000000
# 75%       23.000000
# max       42.000000
# Name: y, dtype: float64

# %%
gsrs_2_common["y"].value_counts(ascending=True)
# Out:
# GUGGUL WHOLE                          1
# GLYCYRRHIZA OFFICINALIS WHOLE         1
# GLYCYRRHIZA BRACHYCARPA WHOLE         1
# SPANISH LIQUORICE WHOLE               1
# GLYCYRRHIZA URALENSIS FISCH EX DC     1
#                                      ..
# ELDERBERRY                           18
# BARBERRY                             18
# COLEUS                               21
# SENNA                                37
# LICORICE                             40
# Name: y, Length: 212, dtype: int64

# %%
all_positives = pd.concat([latin_2_common, common_2_latin, gsrs_2_common], ignore_index=True)

# %%
all_positives["y"].apply(len).describe()
# Out:
# count    3403.000000
# mean       15.087276
# std         5.142847
# min         2.000000
# 25%        11.000000
# 50%        15.000000
# 75%        18.000000
# max        42.000000
# Name: y, dtype: float64

# %%
all_positives["y"].value_counts(ascending=True)
# Out:
# ENDRINO                            1
# QUERCUS MARILANDICA                1
# ANDROPOGON GLOMERATUS              1
# SMILAX LAURIFOLIA                  1
# SCHOENOPLECTUS TABERNAEMONTANI     1
#                                   ..
# ELDERBERRY                        20
# BARBERRY                          20
# COLEUS                            23
# SENNA                             40
# LICORICE                          47
# Name: y, Length: 1875, dtype: int64

# %% [markdown]
# # Data loading and preprocessing

# %% [markdown]
# ## Positive Pairs

# %%
positive_mapped = '../data/NP_FAERS_mapped_20220215.csv'
positive_unmapped = '../data/positive-unmapped-pairs-common-name-or-latin-binomial-copies.tsv'

# %% [markdown]
# # Average NP name length

# %%
pd.read_csv(positive_unmapped, sep='\t')

# %%
main_dataset = pd.read_csv(positive_mapped)
main_dataset.info()

# %%
stats = main_dataset.applymap(len).describe()
stats

# %%
stats = stats["FAERS_drug_match"]
stats["mean"] + stats["std"] * 2

# %%
main_dataset['FAERS_drug_match'].apply(len).sort_values(ascending=False)[:10]

# %%
main_dataset['FAERS_drug_match'].apply(len).gt(100).describe()

# %%
print("Gt 65:", 5358 - 4984)
print("Gt 70:", 5358 - 5212)
print("Gt 80:", 5358 - 5238)
print("Gt 90:", 5358 - 5258)
print("Gt 100:", 5358 - 5288)

# %%
# %matplotlib inline
main_dataset['FAERS_drug_match'].apply(len).hist(bins=15)

# %%
longest = main_dataset['FAERS_drug_match'].apply(len).idxmax()
main_dataset.loc[longest, 'FAERS_drug_match']

# %% [markdown]
# ---

# %% [markdown]
# ## Negative Pairs

# %%
negatives_pairs = '../data/NP_FAERS_negative_pairs_20220222.csv'

# %%
negative_dataset = pd.read_csv(negatives_pairs)
negative_dataset.info()

# %%
negative_dataset.applymap(len).describe()

# %% [markdown]
# ## Test sets

# %%
unmapped_overlap = '../unmapped_data/upper_unmap_orig_drug_names_202201201812.csv'
unmapped_no_overlap = '../data/upper_unmap_orig_drug_names_no_model_overlap_20220224.csv'

# %%
overlap = pd.read_csv(unmapped_overlap)
overlap.info()

# %%
overlap.head()

# %%
no_overlap = pd.read_csv(unmapped_no_overlap)
no_overlap.info()

# %%
no_overlap.head()

# %% [markdown]
# # Complete  Dataset

# %%
complete_dataset = pd.concat([pd.read_pickle("../data/train.pkl"), pd.read_pickle("../data/test.pkl")])

# %%
complete_dataset.loc[complete_dataset["Match"] == 1].sample(100)
# Out:
#                              x                    y  \
# 404555                IWLV AYM             WILD YAM
# 2399200  ICNANMVOMUBB MURWMNAI  CINNAMOMUM BURMANNI
# 1371605  MATRICACIWAQOHCAWOMIL     COMMON CHAMOMILE
# 711455               NKADNLILC          INDIANLILAC
# 603876           WINTWEMHYERRE         WINTERCHERRY
# ...                        ...                  ...
# 1041047      CQIRS UISVENQSIES           TIAN CHENG
# 2275631             MIBES HLBA           ABIES ALBA
# 1258831          ASGSAMVZMNTHA           ASVAGANDHA
# 331732    POTRSELIU MCRYZIYPUM              PARSLEY
# 166879              PHINCSPNIE          PRINCESPINE
#
#                                                Processed_x  \
# 404555   [9, 23, 12, 22, 27, 1, 25, 13, 0, 0, 0, 0, 0, ...
# 2399200  [9, 3, 14, 1, 14, 13, 22, 15, 13, 21, 2, 2, 27...
# 1371605  [13, 1, 20, 18, 9, 3, 1, 3, 9, 23, 1, 17, 15, ...
# 711455   [14, 11, 1, 4, 14, 12, 9, 12, 3, 0, 0, 0, 0, 0...
# ...

# %%
complete_dataset["x"].apply(len).gt(65).value_counts()

# %%
complete_dataset[complete_dataset["x"].apply(len).gt(65)]

# %%
complete_dataset.size

# %%
complete_dataset["y"].value_counts(ascending=True)

# %%
complete_dataset[complete_dataset["Distance"] == 1]["y"].value_counts(ascending=True).plot(rot=90)

# %%
complete_dataset["y"].value_counts(ascending=True)

# %%
complete_dataset["y"].value_counts().mean()

# %%
complete_dataset["y"].value_counts(ascending=True)

# %%
complete_dataset["y"].value_counts(ascending=True).plot(rot=90)

# %%
complete_dataset[(complete_dataset["y"] == "KRATOM") & (complete_dataset["Distance"] == 0)]

# %%
complete_dataset[(complete_dataset["y"] == "GOJI BERRY") & (complete_dataset["Distance"] == 0)]

# %%
complete_dataset[(complete_dataset["y"] == "MITRAGYNA SPECIOSA") & (complete_dataset["Distance"] == 0)]

# %%
one2many = complete_dataset[complete_dataset["Distance"] == 0].groupby(["x"])['y'].count()
one2many[one2many > 1].size

# %%
one2many[one2many > 1].describe()

# %%
one2many[one2many > 1].unique()

# %%
one2many[one2many == 44]

# %%
complete_dataset[complete_dataset["Distance"] == 0][complete_dataset["x"] == "LICORICE"]

# %%
len([{'ARUM ITALICUM'},
 {'EUCLEA RACEMOSA'},
 {'ARCTOSTAPHYLOS NEVADENSIS'},
 {'CARTHAMUS LANATUS'},
 {'AMPELOCISSUS LATIFOLIA'},
 {'CALLICARPA AMERICANA'},
 {'PICEA MARIANA'},
 {'LUPINUS PERENNIS'},
 {'ASARUM CANADENSE'},
 {'ADIANTUM LATIFOLIUM'},
 {'WARBURGIA UGANDENSIS'},
 {'SESELI LIBANOTIS'},
 {'PARONYCHIA ARGENTEA'},
 {'PONTEDERIA CORDATA'},
 {'SPERMACOCE VERTICILLATA'},
 {'ALCEA SETOSA'},
 {'RICINUS COMMUNIS'},
 {'PELTANDRA VIRGINICA'},
 {'CARYA ALBA'},
 {'CASTILLEJA MINIATA'},
 {'CORNUS FLORIDA'},
 {'QUERCUS STELLATA'},
 {'DIANTHUS CARTHUSIANORUM'},
 {'TEUCRIUM CRETICUM'},
 {'TILIA AMERICANA'},
 {'ERYTHRINA CRISTAGALLI'},
 {'QUERCUS CHRYSOLEPIS'},
 {'CROTON DRACONOIDES'},
 {'MERTESIA VIRGINICA'},
 {'ARENARIA LANUGINOSA'},
 {'CIRSIUM ERIOPHORUM'},
 {'MEUM ATHAMANTICUM'},
 {'PINUS ECHINATA'},
 {'ACHILLEA NOBILIS'},
 {'JACOBAEA MARITIMA'},
 {'BAPTISIA ALBA'},
 {'COMMELINA DIFFUSA'},
 {'TODDALIA ASIATICA'},
 {'LUDWIGIA ERECTA'},
 {'ACACIA DEALBATA'},
 {'EUPHORBIA OFFICINARUM'},
 {'RUBUS RIGIDUS'},
 {'FERULA SINKIANGENSIS'},
 {'IPOMOEA WOLCOTTIANA'},
 {'CNIDOSCOLUS URENS'},
 {'ERIGERON STRIGOSUS'},
 {'ALLIUM PORRUM'},
 {'MIKANIA SCANDENS'},
 {'DELPHINIUM GRANDIFLORUM'},
 {'ORIGANUM ONITES'},
 {'DAPHNE GNIDIUM'},
 {'SABAL MINOR'},
 {'OPUNTIA HUMIFUSA'},
 {'ZANTHOXYLUM OVALIFOLIUM'},
 {'AMOMUM AROMATICUM'},
 {'OXYRIA DIGYNA'},
 {'LONICERA HYPOGLAUCA'},
 {'ALOYSIA TRIPHYLLA'},
 {'CYMBOPOGON SCHOENANTHUS'},
 {'CAPSELLA BURSAPASTORIS'},
 {'XANTHIUM STRUMARIUM'},
 {'LUDWIGIA PEPLOIDES'},
 {'JUNCUS TORREYI'},
 {'SCHIZACHYRIUM SCOPARIUM'},
 {'THAPSIA GARGANICA'},
 {'GREWIA VILLOSA'},
 {'CAMPSIS RADICANS'},
 {'LIMONIUM NARBONENSE'},
 {'EICHHORNIA CRASSIPES'},
 {'MONESES UNIFLORA'},
 {'LEPIDIUM DRABA'},
 {'NEPETA HINDOSTANA'},
 {'PLANTAGO ARISTATA'},
 {'SAMBUCUS EBULUS'},
 {'SPHYRNA LEWINI'},
 {'ASCLEPIAS PERENNIS'},
 {'PLECTRANTHUS ESCULENTUS'},
 {'CYCLAMEN HEDERIFOLIUM'},
 {'SALVIA ROSMARINUS'},
 {'BRASSICA BRASSICA OLERACEA'},
 {'PYROSTEGIA VENUSTA'},
 {'BOLETUS EDULIS'},
 {'DIPSACUS FULLONUM'},
 {'PALISOTA HIRSUTA'},
 {'RUBUS CUNEIFOLIUS'},
 {'PLATANTHERA PSYCODES'},
 {'BAUHINIA DIVARICATA'},
 {'ERYTHRINA HERBACEA'},
 {'ASTRAGALUS MONSPESSULANUS'},
 {'QUERCUS GAMBELII'},
 {'SESAMUM RADIATUM'},
 {'TYPHA DOMINGENSIS'},
 {'ZALUZIANSKYA CAPENSIS'},
 {'KALANCHOE CRENATA'},
 {'GARDENIA THUNBERGIA'},
 {'ASCLEPIAS INCARNATA'},
 {'ARTEMISIA ARBORESCENS'},
 {'DAPHNE OLEOIDES'},
 {'MOMORDICA COCHINCHINENSIS'},
 {'MITRACARPUS HIRTUS'},
 {'COLLOMIA LINEARIS'},
 {'GALIUM TRIFLORUM'},
 {'LESSERTIA TOMENTOSA'},
 {'VACCINIUM ANGUSTIFOLIUM'},
 {'ALBIZIA CORIARIA'},
 {'FRAXINUS ANGUSTIFOLIA'},
 {'COMMELINA BENGHALENSIS'},
 {'TEUCRIUM CHAMAEDRYS'},
 {'BRASSICA NIGRA'},
 {'ORBEXILUM PEDUNCULATUM'},
 {'PILOBLEPHIS RIGIDA'},
 {'CERCIS CANADENSIS'},
 {'SALVIA MACROSIPHON'},
 {'WISTERIA SINENSIS'},
 {'ERIGERON FLORIBUNDUS'},
 {'FERULA COMMUNIS'},
 {'HYPERICUM HYPERICOIDES'},
 {'CERINTHE MAJOR'},
 {'TYPHA LATIFOLIA'},
 {'MAESA LANCEOLATA'},
 {'ARUNDO DONAX'},
 {'ENTEROLOBIUM CYCLOCARPUM'},
 {'CLINOPODIUM BOLIVIANUM'},
 {'MIRABILIS JALAPA'},
 {'THELYPTERIS KUNTHII'},
 {'RUBUS FLAGELLARIS'},
 {'CROSSOPTERYX FEBRIFUGA'},
 {'KADSURA JAPONICA'},
 {'STADMANIA OPPOSITIFOLIA'},
 {'SESBANIA SESBAN'},
 {'STACHYS BULLATA'},
 {'ASPARAGUS SETACEUS'},
 {'GENTIANA PNEUMONANTHE'},
 {'MACLURA TINCTORIA'},
 {'HALOXYLON AMMODENDRON'},
 {'CORYLUS AMERICANA'},
 {'VACCINIUM PALLIDUM'},
 {'VINCA MAJOR'},
 {'NASTURTIUM OFFICINALE'},
 {'GRINDELIA CILIATA'},
 {'VERONICA CHAMAEDRYS'},
 {'GALIUM UNIFLORUM'},
 {'CHRYSOPSIS MARIANA'},
 {'PSEUDOGNAPHALIUM VISCOSUM'},
 {'CLINOPODIUM POLYCEPHALUM'},
 {'ZIZANIA AQUATICA'},
 {'ARMILLARIA GALLICA'},
 {'PERIPLOCA LAEVIGATA'},
 {'ALLIUM MACROSTEMON'},
 {'ACALYPHA FRUTICOSA'},
 {'MELILOTUS ALBUS'},
 {'TORMINALIS GLABERRIMA'},
 {'ANEMONE HEPATICA'},
 {'LONICERA PERICLYMENUM'},
 {'CRATAEGUS AZAROLUS'},
 {'QUERCUS ILEX'},
 {'FRANGULA CAROLINIANA'},
 {'ASTRAGALUS PROPINQUUS'},
 {'TEUCRIUM BOTRYS'},
 {'HYPERICUM REVOLUTUM'},
 {'STERCULIA URENS'},
 {'SIDA SPINOSA'},
 {'DIPLOTAXIS TENUIFOLIA'},
 {'ERYTHRINA ABYSSINICA'},
 {'ARISTOLOCHIA FIMBRIATA'},
 {'NEPETA TENUIFOLIA'},
 {'HYPERICUM PUNCTATUM'},
 {'ARISTOLOCHIA RUGOSA'},
 {'THUJA PLICATA'},
 {'TRIGONELLA CORNICULATA'},
 {'SMILAX ROTUNDIFOLIA'},
 {'ERIOGONUM ALATUM'},
 {'NEPHROLEPIS CORDIFOLIA'},
 {'RUDBECKIA HIRTA'},
 {'FOMITOPSIS PINICOLA'},
 {'FICUS SAUSSUREANA'},
 {'CLADIUM MARISCUS'},
 {'ERODIUM MALACOIDES'},
 {'CARYA ILLINOINENSIS'},
 {'VITIS AESTIVALIS'},
 {'TABERNAEMONTANA AURANTIACA'},
 {'SALVIA MICROPHYLLA'},
 {'DICHORISANDRA HEXANDRA'},
 {'ANDROPOGON VIRGINICUS'},
 {'AMBROSIA ARTEMISIIFOLIA'},
 {'CANTINOA AMERICANA'},
 {'GENTIANA OLIVIERI'},
 {'STACHYS TENUIFOLIA'},
 {'EUPATORIUM LINDLEYANUM'},
 {'MAGNOLIA TRIPETALA'},
 {'NIPHIDIUM CRASSIFOLIUM'},
 {'SALIX TRIANDRA'},
 {'LECHEA MINOR'},
 {'BLUMEA LACERA'},
 {'RHEXIA VIRGINICA'},
 {'SPHAGNUM SQUARROSUM'},
 {'PYRUS NIVALIS'},
 {'PERSICARIA MACULOSA'},
 {'AMOMUM ACULEATUM'},
 {'THYMUS PRAECOX'},
 {'SOLANUM CAROLINENSE'},
 {'ZANTHOXYLUM SIMULANS'},
 {'SALIX LUCIDA'},
 {'ENDOTROPIS ALNIFOLIA'},
 {'BIDENS BIPINNATA'},
 {'ACHILLEA AGERATUM'},
 {'KHAYA ANTHOTHECA'},
 {'EUPATORIUM JAPONICUM'},
 {'PISTIA STRATIOTES'},
 {'RUBUS TRIVIALIS'},
 {'PERSICARIA HYDROPIPEROIDES'},
 {'AMANITA RUBESCENS'},
 {'SOLANUM NIGRUM'},
 {'DRIMA MARITIMA'},
 {'POLIOMINTHA INCANA'},
 {'LINARIA VULGARIS'},
 {'CASTANEA MOLLISSIMA'},
 {'SOLANUM LINNAEANUM'},
 {'BOSWELFIA SERRATA'},
 {'OLIVE LEAF'}])

equivalence_group = [{'ASGANDH',
  'ASHWAGANDA',
  'ASHWAGANDHA',
  'ASVAGANDHA',
  'INDIAN GINSENG',
  'WINTERCHERRY',
  'WITHANIA SOMNIFERA'},
 {'BOXHOLLY', 'BUTCHERSBROOM', 'RUSCUS ACULEATUS'},
 {'CATSCLAW', 'UNCARIA TOMENTOSA'},
 {'CAMPHOR',
  'CAMPHOR LAUREL',
  'CAMPHOR TREE',
  'CAMPHORTREE',
  'CASSIA',
  'CASSIA CINNAMON',
  'CEYLON CINNAMON',
  'CHINESE CINNAMON',
  'CHINESE CINNAMON TREE',
  'CINNAMOMUM CAMPHORA',
  'CINNAMOMUM CASSIA',
  'CINNAMOMUM VERUM',
  'CINNAMON',
  'JAPANESE CAMPHOR',
  'KUSONOKI',
  'ROU GUI',
  'TRUE CINNAMON',
  'TVAK'},
 {'COMMON FENUGREEK',
  'FENUGREEK',
  'GREEK HAY',
  'GREEKCLOVER',
  'HU LU BA',
  'TRIGONELFA FOENUM',
  'TRIGONELLA FOENUM'},
 {'FEVERFEW', 'TANACETUM PARTHENIUM'},
 {'FLAX', 'FLAX SEED', 'FLAXSEED', 'LINSEED', 'LINUM USITATISSIMUM'},
 {'GINGER', 'JIANG', 'ZINGIBER OFFICINALE'},
 {'BLACK TEA',
  'CAMELLIA SINENSIS',
  'GREEN TEA',
  'OOLONG TEA',
  'TEA',
  'WHITE TEA'},
 {'GUARANA', 'PAULLINIA CUPANA'},
 {'CANNABIS SATIVA',
  'CANNIBIDIOL',
  'DA MA',
  'HEMP',
  'HEMP EXTRACT',
  'MARIJUANA'},
 {'AESCULUS HIPPOCASTANUM', 'COMMON HORSE CHESTNUT', 'HORSECHESTNUT'},
 {'CURCUMA ZEDOARIA', 'KARCURA'},
 {'KRATOM', 'KRATUM', 'MITRAGYNA SPECIOSA'},
 {'COMMON DANDELION',
  'DANDELION',
  'LIONS TOOTH',
  'LIONSTOOTH',
  'TARAXACUM OFFICINALE'},
 {'GYMNEMA',
  'GYMNEMA SYLVESTRE',
  'LEPIDIUM MEYENII',
  'MACA',
  'MIRACLEFRUIT',
  'PERUVIANGINSENG'},
 {'BENOILTREE',
  'BENZOLIVETREE',
  'DRUMSTICKTREE',
  'HORSERADISHTREE',
  'MALUNGGAY',
  'MORINGA',
  'MORINGA OLEIFERA',
  'WEST INDIAN BEN'},
 {'ARCTIUM LAPPA',
  'BURDOCK',
  'BURR SEED',
  'COCKLEBUR',
  'EDIBLE BURDOCK',
  'GOBO',
  'GOBOSHI',
  'GREAT BURDOCK',
  'GREAT BURDOCKS',
  'GREATER BURDOCK',
  'HARDOCK',
  'HAREBUR',
  'LAPPA',
  'NIU BANG ZI'},
 {'ASIAN GINSENG',
  'CHINESE GINSENG',
  'HONG SHEN',
  'KOREAN GINSENG',
  'KOREAN RED GINSENG',
  'ORIENTAL GINSENG',
  'PANAX GINSENG',
  'RED GINSENG',
  'REN SHEN'},
 {'BLACK SAMPSON',
  'BLACKSAMPSON ECHINACEA',
  'EASTERN PURPLECONEFLOWER',
  'ECHINACEA',
  'ECHINACEA ANGUSTIFOLIA',
  'ECHINACEA PURPUREA',
  'KANSAS SNAKEROOT',
  'NARROWLEAF CONEFLOWER',
  'NARROWLEAF ECHINACEA',
  'NARROWLEAF PURPLECONEFLOWER',
  'PURPLECONEFLOWER'},
 {'GANODERMA', 'GANODERMA LUCIDUM', 'LING ZHI', 'REISHI'},
 {'HONG JING TIAN', 'KINGSCROWN', 'RHODIOLA', 'RHODIOLA ROSEA', 'ROSEROOT'},
 {'SABAL', 'SAW PALMETTO', 'SAWPALMETTO', 'SCRUBPALMETTO', 'SERENOA REPENS'},
 {'RED ELM', 'SLIPPERY ELM', 'ULMUS RUBRA'},
 {'COMMON NETTLE',
  'EUROPEAN NETTLE',
  'GREATER NETTLE',
  'NETTLE',
  'STINGING NETTLE',
  'URTICA DIOICA',
  'YI ZHU QIAN MA'},
 {'HYPERICUM', 'HYPERICUM PERFORATUM', 'ST JOHNS WORT', 'ST JOHNSWORT'},
 {'CELANDINE',
  'CHELIDONIUM MAJUS',
  'GREAT CELANDINE',
  'GREATER CELANDINE',
  'NIPPLEWORT',
  'SWALLOWWORT'},
 {'ANGELICA SINENSIS',
  'CHINESE ANGELICA',
  'DANG QUAI',
  'DANG QUI',
  'DONG GUI',
  'DONG QUAI',
  'TANGKUEI'},
 {'HOLY BASIL', 'OCIMUM TENUIFLORUM', 'RAMA TULSI', 'SACRED BASIL', 'TULSI'},
 {'CRATAEGUS LAEVIGATA',
  'CRATAEGUS MONOGYNA',
  'ENGLISH HAWTHORN',
  'HAWTHORN',
  'MAYTREE',
  'ONESEED HAWTHORN',
  'ONESTYLE HAWTHORN',
  'TWOSTYLE HAWTHORN',
  'WHITETHORN',
  'WOODLAND HAWTHORN'},
 {'DEVILSCLAW', 'GRAPPLE PLANT', 'HARPAGOPHYTUM PROCUMBENS', 'WOOD SPIDER'},
 {'ALOE',
  'ALOE VERA',
  'BARBADOS ALOE',
  'CURAAO ALOE',
  'TRUE ALOE',
  'WEST INDIAN ALOE'},
 {'BEET',
  'BEET ROOT',
  'BETA VULGARIS',
  'FIELD BEET',
  'FODDER BEET',
  'FOLIAGE BEET',
  'GARDEN BEET',
  'MANGEL',
  'MANGELWURZEL',
  'MANGOLD',
  'RED BEET',
  'SICILIAN BROADRIB BEET',
  'SPINACH BEET',
  'SPINACH CHARD',
  'SUGAR BEET',
  'SWISS CHARD',
  'TIAN CAI',
  'YELLOW BEET'},
 {'BLACK CHERRY', 'PRUNUS SEROTINA', 'RUM CHERRY', 'WILD CHERRY'},
 {'AILANTHUS FLAVESCENS WHOLE',
  'AILANTHUS MAIREI WHOLE',
  'CEDRELA GLABRA WHOLE',
  'CEDRELA SINENSIS WHOLE',
  'CORDYCEPS',
  'OPHIOCORDYCEPS SINENSIS',
  'SURENUS SINENSIS WHOLE',
  'TOONA GLABRA WHOLE',
  'TOONA LONGIFOLIA WHOLE',
  'TOONA SINENSIS',
  'TOONA SINENSIS JUSS MROEM',
  'TOONA SINENSIS WHOLE'},
 {'AMERICAN ELDER',
  'BLACK ELDERBERRY WHOLE',
  'CANADIAN ELDER',
  'COMMON ELDERBERRY WHOLE',
  'ELDER WHOLE',
  'ELDERBERRY',
  'ELDERBERRY WHOLE',
  'EUROPEAN BLACK ELDER WHOLE',
  'EUROPEAN BLACK ELDERBERRY WHOLE',
  'EUROPEAN ELDER HOC',
  'EUROPEAN ELDERBERRY WHOLE',
  'SAMBUCUS ALBA WHOLE',
  'SAMBUCUS ARBORESCENS WHOLE',
  'SAMBUCUS AUREA WHOLE',
  'SAMBUCUS CANADENSIS',
  'SAMBUCUS LACINIATA WHOLE',
  'SAMBUCUS NIGRA',
  'SAMBUCUS NIGRA L',
  'SAMBUCUS NIGRA WHOLE',
  'SAMBUCUS PYRAMIDATA WHOLE',
  'SAMBUCUS ROTUNDIFOLIA WHOLE',
  'SAMBUCUS VIRESCENS WHOLE',
  'SAMBUCUS VULGARIS WHOLE',
  'SWEET ELDER'},
 {'GARCINIA',
  'GARCINIA GERRARDII',
  'GARCINIA GERRARDII HARV EX SIM',
  'GARCINIA GERRARDII WHOLE',
  'GARCINIA GUMMI',
  'GARCINIA NATALENSIS WHOLE',
  'GARCINIA TRANSVAALENSIS WHOLE',
  'MALABARTAMARIND'},
 {'HOREHOUND', 'MARRUBIUM VULGARE', 'WHITE HOREHOUND'},
 {'COMMON SCOURINGRUSH',
  'DUTCH RUSH',
  'EQUISETUM HYEMALE',
  'EQUISETUM HYEMALE HPUS',
  'EQUISETUM HYEMALE WHODD',
  'EQUISETUM HYEMALE WHOLE',
  'EQUISETUM PRAEALTUM WHOLE',
  'HIPPOHAETE HYEMALIS WHOLE',
  'HORSETAIL',
  'HORSETAIL EQUISETUM HYEMALE HOC',
  'MU ZEI',
  'ROUGH HORSETAIL',
  'SCOURING HORSETAIL WHOLE',
  'SCOURING RUSH HOC',
  'SCOURINGRUSH',
  'SCOURINGRUSH HORSETAIL WHOLE',
  'TALL SCOURINGRUSH WHOLE',
  'WESTERN SCOURINGRUSH WHOLE'},
 {'ENGELSE HEDERA', 'ENGLISH IVY', 'HEDERA HELIX', 'IVY LEAF'},
 {'KAVA',
  'KAVA PEPPER',
  'KAVAKAVA',
  'KAWA PEPPER',
  'PIPER METHYSTICUM',
  'YANGGONA'},
 {'BLESSED MILK THISTLE',
  'GUNDAGAI THISTLE',
  'HOLY THISTLE',
  'LADYS THISTLE',
  'MARY THISTLE',
  'MARYS THISTLE',
  'MILK THISTLE',
  'SILYBUM MARIANUM',
  'ST MARYS THISTLE',
  'VARIEGATED THISTLE'},
 {'COMMON TURMERIC',
  'CURCUMA',
  'CURCUMA LONGA',
  'INDIANSAFFRON',
  'JIANGHUANG',
  'TURMERIC',
  'YELLOW GINGER'},
 {'COMMON VALERIAN',
  'GARDEN VALERIAN',
  'GARDENHELIOTROPE',
  'VALERIAN',
  'VALERIANA OFFICINALIS'},
 {'BREAD WHEAT', 'TRITICUM AESTIVUM', 'WHEAT', 'WHEAT GRASS', 'XIAO MAI'},
 {'BARLEY GRASS', 'DA MAI', 'HORDEUM VULGARE'},
 {'BLACK CUMIN', 'NIGELLA SATIVA'},
 {'BOSWELLIA', 'BOSWELLIA SERRATA'},
 {'CHLORELLA', 'CHLORELLA VULGARIS'},
 {'ARCTOSTAPHYLOS UVA',
  'BARBERRY',
  'BEARBERRY',
  'BERBERIS ARISTATA',
  'BERBERIS ARISTATA DC',
  'BERBERIS ARISTATA WHODD',
  'BERBERIS ARISTATA WHOLE',
  'BERBERIS BUSSMUL WHOLE',
  'BERBERIS CERATOPHYLLA WHOLE',
  'BERBERIS CHITRIA WHOLE',
  'BERBERIS COCCINEA WHOLE',
  'BERBERIS COERULESCENS WHOLE',
  'BERBERIS GRACILLIMA WHOLE',
  'BERBERIS MACROPHYLLA WHOLE',
  'BERBERIS SERRATIFOLIA WHOLE',
  'BERBERIS SIKKIMENSIS WHOLE',
  'BERBERIS UNDULATA WHOLE',
  'CRANBERRY',
  'DARUHARIDRA WHOLE',
  'DARVI WHOLE',
  'INDIAN BARBERRY',
  'INDIAN BARBERRY HOC',
  'INDIAN BARBERRY WHOLE',
  'KINNIKINNICK',
  'NEPALESE BARBERRY WHOLE',
  'TREETURMERIC',
  'UVA URSI',
  'VACCINIUM MACROCARPON'},
 {'ALLIUM SATIVUM', 'GARLIC'},
 {'STEVIA', 'STEVIA REBAUDIANA'},
 {'FENNEL', 'FENOUIL', 'FOENICULUM VULGARE'},
 {'PAUSINYSTALIA JOHIMBE', 'YOHIMBE'},
 {'COMMON OREGANO', 'OREGANO', 'ORIGANUM VULGARE'},
 {'BLUE CHAMOMILE',
  'CHAMOMILE',
  'COMMON CHAMOMILE',
  'GERMAN CHAMOMILE',
  'HUNGARIAN CHAMOMILE',
  'MATRICARIA',
  'MATRICARIA CHAMOMILLA',
  'SCENTED CHAMOMILE',
  'SCENTED MAYWEED',
  'SWEET FALSE CHAMOMILE',
  'TRUE CHAMOMILE',
  'WILD CHAMOMILE'},
 {'ACTAEA RACEMOSA', 'BLACK BUGBANE', 'BLACK COHOSH', 'BLACK SNAKEROOT'},
 {'ABIES ALBA', 'EUROPEAN SILVER FIR', 'SILVER FIR'},
 {'ACANTHUS MOLLIS', 'BEARS BREECHES'},
 {'ACER FLORIDANUM', 'SUGARMAPLE'},
 {'ACER RUBRUM', 'RED MAPLE', 'ROTAHORN'},
 {'ACHILLEA MILLEFOLIUM', 'COMMON YARROW', 'MILFOIL', 'YARROW'},
 {'ACORUS CALAMUS',
  'CALAMUS',
  'FLAGROOT',
  'MYRTLEFLAG',
  'SWEET CALAMUS',
  'SWEETFLAG',
  'SWEETROOT'},
 {'ADIANTUM CAPILLUS', 'COMMON MAIDENHAIR', 'MAIDENHAIR FERN'},
 {'AFRAMOMUM MELEGUETA', 'GUINEAPEPPER'},
 {'AGATHOSMA BETULINA', 'BUCHU', 'HONEY BUCHU', 'MOUNTAIN BUCHU'},
 {'AGRIMONIA EUPATORIA', 'AGRIMONY', 'DA HUA LONG YA CAO'},
 {'ALBIZIA JULIBRISSIN',
  'HAPPINESS TREE',
  'HE HUAN',
  'MIMOSA',
  'SILKTREE',
  'SILKTREE ALBIZIA'},
 {'ALCHEMILLA XANTHOCHLORA', 'LADYSMANTLE'},
 {'ALLIUM CEPA', 'ONION', 'SHALLOT'},
 {'ALPINIA OFFICINARUM', 'CHINESEGINGER', 'LESSER GALANGA', 'LESSER GALANGAL'},
 {'AMARANTHUS SPINOSUS', 'PRICKLY AMARANTH', 'SPINY AMARANTH'},
 {'AMOMUM VILLOSUM', 'SHA REN', 'SHAREN', 'VILLOUS AMOMUM'},
 {'ANETHUM GRAVEOLENS', 'DILL', 'GARDEN DILL', 'SHI LUO'},
 {'APIUM GRAVEOLENS', 'CELERY'},
 {'AMERICAN SPIKENARD', 'ARALIA RACEMOSA'},
 {'ARALIA SPINOSA', 'CONG MU', 'JAPANESE ANGELICATREE', 'JAPANESE ARALIA'},
 {'ARDISIA CRENATA',
  'CORAL BUSH',
  'CORALBERRY',
  'CORALBERRY TREE',
  'HENSEYES',
  'KORAALBESSIEBOOM',
  'SPICEBERRY',
  'ZHU SHA GEN'},
 {'ARECA CATECHU', 'ARECA PALM', 'BING LANG'},
 {'ARISTOTELIA CHILENSIS', 'MAQUI'},
 {'ABSINTHE',
  'ABSINTHE WORMWOOD',
  'ABSINTHIUM',
  'ARTEMISIA ABSINTHIUM',
  'WORMWOOD'},
 {'ARTEMISIA ANNUA', 'HUANG HUA HAO', 'SWEET ANNIE', 'SWEET WORMWOOD'},
 {'ARTOCARPUS ALTILIS', 'BREADFRUIT'},
 {'ASPARAGUS RACEMOSUS', 'SHATAMULI', 'SHATAVARI'},
 {'ATRACTYLODES LANCEA', 'MAOCANGZHU'},
 {'ATRACTYLODES MACROCEPHALA',
  'BAI ZHU',
  'BAI ZHU ATRACTYLODES',
  'LARGEHEAD ATRACTYLODES',
  'WHITE ATRACTYLODES'},
 {'AZADIRACHTA INDICA', 'INDIANLILAC', 'MARGOSA', 'NEEM', 'NIMTREE'},
 {'BACOPA', 'BACOPA MONNIERI', 'MONEYWORT', 'WATER HYSSOP'},
 {'BALLOTA',
  'BALLOTA NIGRA',
  'BLACK HEMPNETTLE',
  'BLACK HOREHOUND',
  'BLACK STINKING HOREHOUND',
  'MARRUBIUM NIGRUM'},
 {'BERBERIS AQUIFOLIUM',
  'BLUE BARBERRY',
  'HOLLY BARBERRY',
  'HOLLY MAHONIA',
  'MAHONIA',
  'MOUNTAIN GRAPE',
  'MOUNTAINGRAPE',
  'OREGON GRAPE',
  'OREGONGRAPE'},
 {'BERBERIS LYCIUM', 'BERBERISLYCIUM'},
 {'BERBERIS VULGARIS',
  'COMMON BARBERRY',
  'EUROPEAN BARBERRY',
  'JAUNDICEBERRY',
  'PIPRAGE'},
 {'BIDENS PILOSA', 'HAIRY BEGGARTICKS', 'SPANISHNEEDLES'},
 {'ANNATTO', 'ARNATTO', 'BIXA ORELLANA', 'LIPSTICKTREE', 'ROCOU'},
 {'BEEBREAD',
  'BEEPLANT',
  'BORAGE',
  'BORAGO OFFICINALIS',
  'STARFLOWER',
  'TALEWORT'},
 {'BRASSICA JUNCEA', 'INDIAN MUSTARD', 'ORIENTAL MUSTARD'},
 {'BRASSICA OLERACEA', 'COLZA', 'RAPE', 'RAPE SEED', 'SEED RAPE'},
 {'BRASSICA RAPA', 'RAPINI', 'SEVENTOP TURNIP', 'TURNIP', 'TYFON'},
 {'BEI CHAI HU',
  'BUPLEURUM',
  'BUPLEURUM CHINENSE',
  'CHAI HU',
  'CHINESE THOROUGHWAX',
  'HARESEAR'},
 {'CALLUNA VULGARIS',
  'COMMON HEATHER',
  'HEATHER',
  'LING',
  'REDHEATH',
  'SCOTCH HEATHER',
  'SCOTS HEATHER'},
 {'CAPER', 'CAPERBUSH', 'CAPPARIS SPINOSA'},
 {'CAPSELLA BURSA', 'SHEPHERDSPURSE'},
 {'AMERICANCHESTNUT', 'CASTANEA DENTATA'},
 {'CASTANEA SATIVA', 'EUROPEAN CHESTNUT', 'SWEET CHESTNUT'},
 {'BLUE COHOSH',
  'CAULOPHYLLUM',
  'CAULOPHYLLUM THALICTROIDES',
  'PAPOOSEROOTT',
  'SQUAWROOT'},
 {'CENTAURIUM ERYTHRAEA',
  'CENTAURY',
  'COMMON CENTAURY',
  'EUROPEAN CENTAURY',
  'SMALL CENTAURY'},
 {'BREAD ST JOHNS',
  'CAROB',
  'CERATONIA',
  'CERATONIA SILIQUA',
  'LOCUSTBEAN',
  'ST JOHNS BREAD',
  'ST JOHNSBREAD'},
 {'BITTER WINTERGREEN',
  'CHIMAPHILA UMBELLATA',
  'GROUND IVY',
  'PIPSISSEWA',
  'PIPSISSIWA',
  'PRINCESPINE'},
 {'CHIONANTHUS VIRGINICUS', 'FRINGETREE', 'OLDMANSBEARD', 'POISONASH'},
 {'BELGIUM ENDIVE', 'CHICORY', 'CICHORIUM INTYBUS', 'RADICCHIO'},
 {'BATAVIACINNAMON', 'CINNAMOMUM BURMANNI'},
 {'CISTUS CRETICUS', 'HAIRYROCKROSE'},
 {'CITRULLUS LANATUS', 'WATERMELON'},
 {'BITTER ORANGE', 'CITRUS AURANTIUM', 'SEVILLE ORANGE', 'SUAN CHENG'},
 {'CITRUS PARADISI', 'GRAPEFRUIT'},
 {'CITRUS RETICULATA', 'JU', 'MANDARIN ORANGE', 'TANGERINE'},
 {'BLOOD ORANGE',
  'CITRUS SINENSIS',
  'NAVEL ORANGE',
  'RED ORANGE',
  'SWEET ORANGE',
  'TIAN CHENG',
  'VALENCIA ORANGE'},
 {'BELLFLOWER', 'CODONOPSIS PILOSULA', 'DANG SHEN'},
 {'BITTER COLA', 'COLA NITIDA', 'GBANJA KOLA', 'KOLA'},
 {'BALSAMEA MUKUL WHOLE',
  'BALSAMODENDRUM MUKUL WHOLE',
  'BDELLIUM TREE WHOLE',
  'COMMIPHORA MUKUL',
  'COMMIPHORA MUKUL HOOK EX STOCKS ENGL',
  'COMMIPHORA MUKUL WHODD',
  'COMMIPHORA MUKUL WHOLE',
  'COMMIPHORA ROXBURGHII WHOLE',
  'FALSE MYRRH WHOLE',
  'GUGGUL',
  'GUGGUL HOC',
  'GUGGUL WHOLE',
  'GUGGULU WHOLE',
  'GUGUL',
  'INDIAN BDELLIUMTREE'},
 {'BUTTERWEED', 'CANADIAN HORSEWEED', 'CONYZA CANADENSIS'},
 {'CHINESE GOLDTHREAD',
  'CHINESE GOLDTHREAD WHOLE',
  'COPTIS',
  'COPTIS CHINENSIS',
  'COPTIS CHINENSIS FRANCH',
  'COPTIS CHINENSIS WHODD',
  'COPTIS CHINENSIS WHOLE',
  'COPTIS COPTIS CHINENSIS HOC',
  'GOLDEN THREAD',
  'HUANG LIAN',
  'HUANG LIAN WHOLE',
  'HUANGLIAN'},
 {'CORDYCEPS MILITARIS', 'CORDYCEPSMILITARIS'},
 {'CHINESE PARSLEY',
  'CHINESEPARSLEY',
  'CILANTRO',
  'CORIANDER',
  'CORIANDRUM SATIVUM',
  'PARSLEY CHINESE'},
 {'ASIATIC CORNELIAN CHERRY',
  'ASIATIC DOGWOOD',
  'CORNUS OFFICINALIS',
  'SHAN ZHU YU'},
 {'COBNUT',
  'CORYLUS AVELLANA',
  'EUROPEAN FILBERT',
  'EUROPEAN HAZEL',
  'GIANT FILBERT',
  'HAZEL',
  'HAZELNUT TREE'},
 {'CRITHMUM MARITIMUM', 'ROCK SAMPHIRE', 'SEAFENNEL'},
 {'CUMIN', 'CUMINUM CYMINUM'},
 {'COCOGRASS',
  'CYPERUS ROTUNDUS',
  'NUT SEDGE',
  'NUTGRASS',
  'NUTGRASS ALINGALE',
  'PURPLE NUT SEDGE',
  'RED NUT SEDGE',
  'SUO CAO',
  'XIANG FU ZI',
  'XIANGFU'},
 {'CARROT', 'DAUCUS CAROTA'},
 {'CHINAROOT', 'DIOSCOREA VILLOSA', 'WILD YAM'},
 {'AMERICANPERSIMMON', 'DIOSPYROS VIRGINIANA'},
 {'CI WU JIA', 'ELEUTHERO', 'ELEUTHEROCOCCUS SENTICOSUS', 'SIBERIAN GINSENG'},
 {'COUCHGRASS', 'ELYMUS REPENS'},
 {'CUPIDS SHAVINGBRUSH', 'EMILIA', 'EMILIA SONCHIFOLIA', 'SOW THISTLE'},
 {'BARRENWORT',
  'EPIMEDIUM EPIMEDIUM PUBESCENS HOC',
  'EPIMEDIUM GRANDIF',
  'EPIMEDIUM GRANDIFLORUM',
  'EPIMEDIUM PUBESCENS',
  'EPIMEDIUM PUBESCENS MAXIM',
  'EPIMEDIUM PUBESCENS WHOLE',
  'HERBA EPIMEDII WHOLE',
  'HORNY GOAT WEED',
  'JAPANESE EPIMEDIUM',
  'PUBESCENT EPIMEDIUM WHOLE',
  'ROU MA YIN YANG HUO WHOLE',
  'YIN YANG HUO',
  'YINYANGHUO WHOLE'},
 {'BIBASSE',
  'ERIOBOTRYA JAPONICA',
  'JAPANESEMEDLAR',
  'LOQUAT',
  'LUKWART',
  'NISPERO',
  'PI BA'},
 {'ERIODICTYON CALIFORNICUM', 'MOUNTAIN BALM', 'YERBASANTA'},
 {'ARUGULA', 'ERUCA VESICARIA', 'GARDEN ROCK'},
 {'CALIFORNIAPOPPY', 'ESCHSCHOLZIA CALIFORNICA'},
 {'DROPWORT',
  'EUPATORIUM PURPUREUM',
  'FILIPENDULA ULMARIA',
  'GRAVELROOT',
  'GREENSTEM JOEPYEWEED',
  'JOEPYE',
  'JOEPYEWEED',
  'MARSHMILKWEED',
  'MEADOWSWEET',
  'QUEENOFTHEMEADOW',
  'SWEET JOEPYEWEED',
  'XUAN GUO WEN ZI CAO'},
 {'AAI', 'ACAI', 'ASSAI PALM', 'CABBAGE PALM', 'EUTERPE OLERACEA'},
 {'FERULA ELAEOCHYTRIS', 'FERULAELAEOCHYTRIS'},
 {'FICUS CARICA', 'FIG', 'FIG TREE', 'WU HUA GUO'},
 {'FOMES FOMENTARIUS', 'FOMESFOMENTARIUS'},
 {'ALDER BUCKTHORN', 'FRANGULA', 'FRANGULA ALNUS', 'GLOSSY BUCKTHORN'},
 {'BLACK TANG', 'BLADDER FUCUS', 'FUCUS VESICULOSUS', 'KELPWARE', 'SEAWRACK'},
 {'COMMON FUMITORY', 'FUMARIA OFFICINALIS', 'FUMITORY', 'WAXDOLLS'},
 {'FRENCH LILAC', 'GALEGA', 'GALEGA OFFICINALIS', 'GOATSRUE'},
 {'CATCHWEED BEDSTRAW', 'CLEAVERS', 'GALIUM APARINE', 'GOOSEGRASS'},
 {'GALIUM VERUM', 'LADYS BEDSTRAW', 'YELLOW BEDSTRAW'},
 {'BITTERWORT', 'GENTIAN', 'GENTIANA LUTEA', 'GENTIANROOT', 'YELLOW GENTIAN'},
 {'CRANESBILL', 'GERANIUM MACULATUM', 'SPOTTED GERANIUM', 'WILD GERANIUM'},
 {'BAIGUO', 'GINKGO', 'GINKGO BILOBA', 'ICHO', 'MAIDENHAIRTREE'},
 {'BLACK SOYA BEAN',
  'DA DOU',
  'GLYCINE MAX',
  'SOY',
  'SOYA',
  'SOYABEAN',
  'SOYBEAN'},
 {'CHINESE LICORICE',
  'CHINESE LICORICE GLYCYRRHIZA INFLATA HOC',
  'CHINESE LICORICE GLYCYRRHIZA URALENSIS HOC',
  'COMMON LICORICE WHOLE',
  'COMMON LIQUORICE WHOLE',
  'CULTIVATED LICORICE WHOLE',
  'GAN CAO',
  'GAN CAO WHOLE',
  'GLYCYRRHIZA BRACHYCARPA WHOLE',
  'GLYCYRRHIZA EURYCARPA WHOLE',
  'GLYCYRRHIZA GLABRA',
  'GLYCYRRHIZA GLABRA L',
  'GLYCYRRHIZA GLABRA WHODD',
  'GLYCYRRHIZA GLABRA WHOLE',
  'GLYCYRRHIZA GLANDULIFERA WHOLE',
  'GLYCYRRHIZA HEDINIANA WHOLE',
  'GLYCYRRHIZA HIRSUTA WHOLE',
  'GLYCYRRHIZA INFLATA',
  'GLYCYRRHIZA INFLATA BATALIN',
  'GLYCYRRHIZA INFLATA WHODD',
  'GLYCYRRHIZA INFLATA WHOLE',
  'GLYCYRRHIZA LAEVIS WHOLE',
  'GLYCYRRHIZA OFFICINALIS WHOLE',
  'GLYCYRRHIZA PALLIDA WHOLE',
  'GLYCYRRHIZA PAUCIFOLIOLATA WHOLE',
  'GLYCYRRHIZA URALENSIS',
  'GLYCYRRHIZA URALENSIS FISCH EX DC',
  'GLYCYRRHIZA URALENSIS WHODD',
  'GLYCYRRHIZA URALENSIS WHOLE',
  'GLYCYRRHIZA VIOLACEA WHOLE',
  'GLYCYRRHIZA VULGARIS WHOLE',
  'GUANG GUO GAN CAO',
  'GUANG GUO GAN CAO WHOLE',
  'LICORICE',
  'LICORICE GLYCYRRHIZA GLABRA HOC',
  'LIQUIRITIA OFFICINALIS WHOLE',
  'LIQUIRITIA OFFICINARUM WHOLE',
  'LIQUORICE',
  'MERISTOTROPIS PAUCIFLORA WHOLE',
  'MERISTOTROPIS PAUCIFOLIOLATA WHOLE',
  'RUSSIAN LICORICE WHOLE',
  'SPANISH LICORICE WHOLE',
  'SPANISH LIQUORICE WHOLE',
  'TURKISH LICORICE WHOLE',
  'URAL LICORICE WHOLE',
  'WU LA GAN CAO WHOLE',
  'XINJIANG LICORICE WHOLE',
  'YASHTIMADHU WHOLE',
  'ZHANGGUOGANCAO'},
 {'HAMAMELIS',
  'HAMAMELIS VIRGINIANA',
  'SPOTTED ALDER',
  'WINTER BLOOM',
  'WITCHAZEL',
  'WITCHHAZEL'},
 {'HANDROANTHUS HEPTAPHYLLUS',
  'IPE ROXO',
  'LAPACHO',
  'LAPACHO NEGRO',
  'PAU DARCO'},
 {'EVERLASTING',
  'HELICHRYSUM ARENARIUM',
  'IMMORTELLE',
  'SANDY EVERLASTING',
  'YELLOW CHASTEWEED'},
 {'GOLDENSEAL',
  'GOLDENSEAL HOC',
  'GOLDENSEAL WHOLE',
  'HYDRASTIS CANADENSIS',
  'HYDRASTIS CANADENSIS L',
  'HYDRASTIS CANADENSIS WHOLE',
  'HYDRASTIS TRIFOLIA WHOLE',
  'ORANGEROOT',
  'WARNERIA CANADENSIS WHOLE',
  'YELLOW PUCCOON WHOLE',
  'YELLOW ROOT',
  'YELLOW WHOLE',
  'YELLOWPUCCOON'},
 {'HYSSOP', 'HYSSOPUS OFFICINALIS'},
 {'BRAZILIAN TEA',
  'ILEX PARAGUARIENSIS',
  'MATE',
  'PARAGUAY TEA',
  'PARAGUAYAN TEA',
  'ST BARTHOLOMEWS TEA',
  'YERBA MATE'},
 {'CHAGA', 'INONOTUS OBLIQUUS'},
 {'AARONSROD',
  'COMMON MULLEIN',
  'ELECAMPANE',
  'FLANNELLEAF',
  'FLANNELPLANT',
  'GREAT MULLEIN',
  'HAG TAPER',
  'INULA HELENIUM',
  'MULLEIN',
  'TORCHES',
  'TU MU XIANG',
  'VELVETDOCK',
  'VERBASCUM THAPSUS'},
 {'BLACKWALNUT', 'JUGLANS NIGRA'},
 {'JUGLANS REGIA', 'WALNUT'},
 {'COMMON RUSH', 'DENG XIN CAO', 'JUNCUS EFFUSUS', 'SOFT RUSH'},
 {'COMMON JUNIPER', 'JUNIPER', 'JUNIPERUS COMMUNIS'},
 {'CADE JUNIPER',
  'JUNIPERUS OXYCEDRUS',
  'PRICKLY JUNIPER',
  'REDBERRY JUNIPER'},
 {'EASTERN REDCEDAR',
  'JUNIPERUS VIRGINIANA',
  'PENCILCEDAR',
  'POTLOODSEDER',
  'RED JUNIPER',
  'REDCEDAR',
  'ROOISEDE'},
 {'COMMON MOTHERWORT', 'LEONURUS CARDIACA', 'MOTHERWORT'},
 {'DU XING CAI', 'LEPIDIUM', 'PEPPERWEED'},
 {'LEVISTICUM OFFICINALE', 'LOVAGE'},
 {'LILIUM CANDIDUM', 'MADONNA LILY', 'WHITE LILY'},
 {'ALLIGATORWOOD',
  'AMERICANSTORAX',
  'LIQUIDAMBAR STYRACIFLUA',
  'REDGUM',
  'SATINWALNUT',
  'SWEETGUM'},
 {'LOBARIA PULMONARIA', 'LUNG LICHEN', 'LUNGMOSS'},
 {'JAPANESE HONEYSUCKLE',
  'JIN YIN HUA',
  'LONICERA JAPONICA',
  'REN DONG',
  'RENDONGTENG'},
 {'BARBARY MATRIMONYVINE',
  'BARBARY WOLFBERRY',
  'CHINESE WOLFBERRY',
  'GOJI BERRY',
  'LYCIUM BARBARUM',
  'MATRIMONYVINE',
  'NING XIA GOU QI'},
 {'AMERICANBUGLEWEED', 'LYCOPUS AMERICANUS'},
 {'BULL BAY', 'LAURIER TULIPIER', 'MAGNOLIA GRANDIFLORA', 'SOUTHERN MAGNOLIA'},
 {'HOU PO', 'MAGNOLIA OFFICINALIS', 'MAGNOLIABARK'},
 {'MAGNOLIA VIRGINIANA', 'SWEETBAY'},
 {'APPLE CIDER VINEGAR', 'MALUS DOMESTICA', 'MALUS PUMILA'},
 {'BLUE MALLOW',
  'CHEESES',
  'COMMON MALLOW',
  'HIGH MALLOW',
  'MALVA SYLVESTRIS',
  'TALL MALLOW'},
 {'BUR MEDIC',
  'CALIFORNIA BURCLOVER',
  'HAIRY MEDIC',
  'MEDICAGO POLYMORPHA',
  'TOOTHED BURCLOVER',
  'TOOTHED MEDIC'},
 {'CHINABERRY',
  'LIAN',
  'MELIA AZEDARACH',
  'PERSIAN LILAC',
  'SICHUAN PAGODATREE',
  'SZECHWAN CHINABERRY'},
 {'BALM', 'BEE BALM', 'LEMON BALM', 'MELISSA', 'MELISSA OFFICINALIS'},
 {'EUROPEAN PENNYROYAL',
  'LURKINTHEDITCH',
  'MENTHA PULEGIUM',
  'MOSQUITO PLANT',
  'PENNYROYAL',
  'PUDDING GRASS',
  'PULEGIUM',
  'RUNBYTHEGROUND',
  'SQUAW BALM',
  'SQUAWMINT TICKWEED'},
 {'CURLED MINT', 'MENTHA SPICATA', 'SPEARMINT'},
 {'HAN XIU CAO', 'MIMOSA PUDICA', 'SENSITIVEPLANT', 'TOUCHMENOT'},
 {'MITCHELLA REPENS', 'PARTRIDGEBERRY', 'SQUAWVINE'},
 {'BALSAMAPPLE',
  'BALSAMPEAR',
  'BITTER GOURD',
  'BITTER MELON',
  'BITTERCUCUMBER',
  'CARILLA GOURD',
  'MOMORDICA CHARANTIA'},
 {'BAYBERRY',
  'CANDLEBERRY',
  'MORELLA CERIFERA',
  'SOUTHERN BAYBERRY',
  'SOUTHERN WAXMYRTLE',
  'WAXBERRY',
  'WAXMYRTLE'},
 {'INDIANMULBERRY', 'MORINDA CITRIFOLIA', 'NONI', 'ROTTEN CHEESEFRUIT'},
 {'MYRTLE', 'MYRTUS COMMUNIS'},
 {'CATMINT', 'CATNEP', 'CATNIP', 'CATSWORT', 'FIELD BALM', 'NEPETA CATARIA'},
 {'NERIUM OLEANDER', 'OLEANDER', 'ROSE LAUREL'},
 {'GAVILANA', 'JACKASS BITTERS', 'NEUROLAENA LOBATA'},
 {'NOTOPTERYGIUM', 'NOTOPTERYGIUM INCISUM', 'QIANG HUO'},
 {'NYMPHAEA ODORATA', 'SWEETWATERLILY'},
 {'EVENING PRIMROSE OIL', 'OENOTHERA BIENNIS'},
 {'OLEA EUROPAEA', 'OLIVE', 'OLIVE TREE', 'OLIVELEAF'},
 {'ONONIS',
  'ONONIS SPINOSA',
  'RESTHARROW',
  'SPINY RESTHARROW',
  'SPRING RESTHARROW'},
 {'DEVILSCLUB', 'OPLOPANAX HORRIDUS'},
 {'MOROCCANOREGANO', 'ORIGANUM COMPACTUM'},
 {'MARJORAM', 'ORIGANUM MAJORANA', 'SWEET MARJORAM'},
 {'BIBLICAL HYSSOP',
  'LEBANESE OREGANO',
  'ORIGANUM SYRIACUM',
  'SYRIAN OREGANO'},
 {'ORYZA SATIVA', 'RED YEAST RICE'},
 {'CORN POPPY',
  'FIELD POPPY',
  'FLANDERS POPPY',
  'PAPAVER RHOEAS',
  'SHIRLEY POPPY'},
 {'PARIETARIA JUDAICA', 'PELLITORYOFTHEWALL', 'SPREADING PELLITORY'},
 {'PASSIFLORA EDULIS', 'PURPLEGRANADILLA'},
 {'PARSLEY', 'PETROSELINUM CRISPUM'},
 {'BOLDO', 'BOLDO TREE', 'BOLDU', 'PEUMUS BOLDUS'},
 {'PHYLLANTHUS AMARUS', 'PHYLLANTHUSAMARUS'},
 {'CHUI XU SHANG LU',
  'PHYTOLACCA AMERICANA',
  'PIGEONBERRY',
  'POKE',
  'POKEBERRY',
  'POKEROOT',
  'POKEWEED',
  'VIRGINIA POKE'},
 {'DWARF PINE',
  'MOUNTAIN PINE',
  'MOUNTAIN PINE SWISS',
  'MUGO PINE',
  'PINE PUMILIO',
  'PINE SWISS MOUNTAIN',
  'PINUS MUGO',
  'PUMILIO PINE',
  'SCRUB MOUNTAIN PINE',
  'SWISS MOUNTAIN PINE'},
 {'BALTIC REDWOOD',
  'PINUS NIGRA',
  'PINUS SYLVESTRIS',
  'SCOTCH PINE',
  'SCOTS PINE'},
 {'LONGLEAF PINE', 'PINUS PALUSTRIS', 'PITCH PINE'},
 {'BLACK PEPPER',
  'BLACK PEPPER WHOLE',
  'MULDERA MULTINERVIS WHOLE',
  'PEPPER BLACK',
  'PEPPER HOC',
  'PEPPER WHITE',
  'PIPER NIGRUM',
  'PIPER NIGRUM L',
  'PIPER NIGRUM WHOLE',
  'WHITE PEPPER'},
 {'PIPTOPORUS BETULINUS', 'PIPTOPORUSBETULINUS'},
 {'CHIOS MASTICTREE', 'LENTISCUS', 'PISTACIA LENTISCUS'},
 {'BROADLEAF PLANTAIN',
  'COMMON PLANTAIN',
  'GREATER PLANTAIN',
  'PLANTAGO MAJOR',
  'PLANTAIN'},
 {'AMERICANSYCAMORE', 'PLATANUS OCCIDENTALIS'},
 {'CABLIN PATCHOULI',
  'GUANG HUO XIANG',
  'PATCHOULIPLANT',
  'PATCHOULY',
  'POGOSTEMON CABLIN'},
 {'MEDITERRANEANTAPEWEED', 'POSIDONIA OCEANICA'},
 {'COMMON SELFHEAL',
  'HEALALL',
  'PRUNELLA',
  'PRUNELLA VULGARIS',
  'SELFHEAL',
  'WOUNDWORT',
  'XIAKUCAO'},
 {'APRICOT', 'PRUNUS ARMENIACA', 'SIBERIAN APRICOT', 'XING'},
 {'MOMO', 'PEACH', 'PRUNUS PERSICA', 'TAO'},
 {'BLACKTHORN', 'ENDRINO', 'PRUNUS SPINOSA'},
 {'BLUNTLEAVED EVERLASTING',
  'FRAGRANT EVERLASTING',
  'PSEUDOGNAPHALIUM OBTUSIFOLIUM'},
 {'DOUGLASFIR', 'PSEUDOTSUGA MENZIESII'},
 {'HOPTREE', 'PTELEA TRIFOLIATA', 'SHRUBTREFOIL'},
 {'QUASSIA', 'QUASSIA AMARA', 'QUASSIA WOOD'},
 {'QUERCUS ALBA', 'STAVE OAK', 'WHITE OAK'},
 {'BLUEJACKOAK', 'QUERCUS INCANA'},
 {'JOINTED CHARLOCK', 'RAPHANUS RAPHANISTRUM', 'WILD RADISH'},
 {'FLEECEFLOWER', 'FOTI', 'HE SHOU WU', 'REYNOUTRIA MULTIFLORA'},
 {'HIMALAYAN RHUBARB',
  'HIMALAYARHABARBER',
  'INDIAN RHUBARB',
  'RHEUM',
  'RHEUM AUSTRALE',
  'ZANG BIAN DA HUANG'},
 {'CHINESE RHUBARB',
  'ORNAMENTAL RHUBARB',
  'RHEUM PALMATUM',
  'RHUBARB',
  'ZHANG YE DA HUANG'},
 {'RHUS CORIARIA', 'SICILIAN SUMAC', 'TANNERS SUMAC'},
 {'BLACK LOCUST', 'FALSA ACACIA', 'ROBINIA PSEUDOACACIA'},
 {'COMMON BRIAR', 'DOG ROSE', 'DOGBRIER', 'ROSA CANINA'},
 {'ROSEMARY', 'ROSMARINUS OFFICINALIS'},
 {'BOYSENBERRY', 'RUBUS URSINUS'},
 {'CURLY DOCK', 'RUMEX CRISPUS', 'SOUR DOCK', 'YELLOW DOCK'},
 {'FRINGEDRUE', 'RUTA CHALEPENSIS'},
 {'RUE', 'RUTA GRAVEOLENS'},
 {'COMMON SAGE',
  'DALMATIAN SAGE',
  'GARDEN SAGE',
  'SAGE',
  'SALVIA OFFICINALIS'},
 {'MEADOW CLARY', 'MEADOW SAGE', 'SALVIA PRATENSIS'},
 {'CLARY', 'CLARY SAGE', 'SALVIA SCLAREA'},
 {'BLOODROOT',
  'BLOODWORT',
  'CANADIAN BLOODROOT',
  'RED PUCCOON',
  'REDROOT',
  'SANGUINARIA CANADENSIS',
  'TETTERWORT'},
 {'BOUNCINGBET', 'SAPONARIA OFFICINALIS', 'SOAPWORT'},
 {'FANG FENG', 'SAPOSHNIKOVIA DIVARICATA', 'SILER'},
 {'SARGASSUM PALLIDUM', 'SARGASSUMPALLIDUM'},
 {'COMMON SASSAFRAS', 'SASSAFRAS', 'SASSAFRAS ALBIDUM', 'WHITE SASSAFRAS'},
 {'SATUREJA MONTANA', 'SAVORY', 'WINTER SAVORY'},
 {'CHINESE MAGNOLIAVINE', 'SCHISANDRA', 'SCHISANDRA CHINENSIS', 'WU WEI ZI'},
 {'HELMET FLOWER',
  'HOODWORT',
  'MADDOG SCULLCAP',
  'QUARTER BONNET',
  'SCULLCAP',
  'SCUTELLARIA LATERIFLORA',
  'SKULLCAP',
  'VIRGINIAN SKULLCAP'},
 {'AFRIKANSKAYA SENNA WHOLE',
  'ALEXANDRIAN SENNA WHOLE',
  'BHUIKHAKHASA WHOLE',
  'BOMBAY SENNA WHOLE',
  'CASSE WHOLE',
  'CASSIA ACUTIFOLIA WHOLE',
  'CASSIA AETHIOPICA WHOLE',
  'CASSIA ALEXANDRINA WHOLE',
  'CASSIA ANGUSTIFOLIA WHOLE',
  'CASSIA DECIPIENS WHOLE',
  'CASSIA EHRENBERGII WHOLE',
  'CASSIA ELONGATA WHOLE',
  'CASSIA LANCEOLATA WHOLE',
  'CASSIA LENITIVA WHOLE',
  'CASSIA LIGUSTRINOIDES WHOLE',
  'CASSIA MEDICA WHOLE',
  'CASSIA MEDICINALIS WHOLE',
  'CASSIA ORIENTALIS WHOLE',
  'CASSIA OVATA WHOLE',
  'CASSIA SENNA WHOLE',
  'HINDISANA WHOLE',
  'INDIAN SENNA WHOLE',
  'JALELO WHOLE',
  'KASSIYA OSTROLISTNAYA WHOLE',
  'SANA WHOLE',
  'SENNA',
  'SENNA ACUTIFOLIA WHOLE',
  'SENNA ALEXANDRINA',
  'SENNA ALEXANDRINA MILL',
  'SENNA ALEXANDRINA WHODD',
  'SENNA ALEXANDRINA WHOLE',
  'SENNA ANGUSTIFOLIA WHOLE',
  'SENNA HOC',
  'SENNA OFFICINALIS WHOLE',
  'SENNA WHOLE',
  'SENNAIMAKKI WHOLE',
  'SVARNAPATRI WHOLE',
  'TINNEVELLY SENNA WHOLE',
  'TRUE SENNA WHOLE'},
 {'JAVABEAN', 'SENNA OBTUSIFOLIA', 'SICKLEPOD', 'SICKLEPOD SENNA'},
 {'ANTBUSH',
  'COFFEE SENNA',
  'NEGROCOFFEE',
  'SENNA OCCIDENTALIS',
  'STINKINGWEED'},
 {'HEDGEMUSTARD', 'SISYMBRIUM OFFICINALE'},
 {'POISONBERRY', 'SOLANUM ANGUIVI'},
 {'CANADIANGOLDENROD', 'SOLIDAGO CANADENSIS'},
 {'ANISESCENT GOLDENROD', 'FRAGRANT GOLDENROD', 'SOLIDAGO ODORA'},
 {'BISHOPSWORT', 'PURPLE BETONY', 'STACHYS OFFICINALIS', 'WOOD BETONY'},
 {'QUEENSDELIGHT',
  'QUEENSROOT',
  'STILLINGIA',
  'STILLINGIA SYLVATICA',
  'YAWROOT'},
 {'CHIRATA', 'CHIRETTA', 'KIRATATIKTA', 'SWERTIA CHIRATA'},
 {'BONESET',
  'COMFREY',
  'COMMON COMFREY',
  'CONSOUND',
  'HEALINGHERB',
  'KNITBONE',
  'SLIPPERYROOT',
  'SYMPHYTUM OFFICINALE'},
 {'INDIAN TAMARIND', 'KILYTREE', 'TAMARIN', 'TAMARIND', 'TAMARINDUS INDICA'},
 {'GOLDENBUTTONS', 'TANACETUM VULGARE', 'TANSY'},
 {'COMMON THYME',
  'CONEHEAD THYME',
  'ENGLISH THYME',
  'FRENCH THYME',
  'GARDEN THYME',
  'THYME',
  'THYMUS VULGARIS'},
 {'SPANISHMOSS', 'TILLANDSIA USNEOIDES'},
 {'KAWARATAKE', 'TRAMETES VERSICOLOR', 'TURKEY TAIL', 'YUNZHI'},
 {'CALTROP',
  'CATSHEAD',
  'COMMON DUBBLETJIE',
  'DEVILSTHORN',
  'DEVILSWEED',
  'GOATHEAD',
  'GOKSHURA',
  'GOKSURA',
  'JI LI',
  'PUNCTUREVINE',
  'PUNCTUREVINE CALTROP',
  'TRIBULUS',
  'TRIBULUS TERRESTRIS'},
 {'DAMIANA', 'TURNERA DIFFUSA'},
 {'COLTSFOOT',
  'COMMON COLTSFOOT',
  'KUAN DONG',
  'KUANDONGHUA',
  'TUSSILAGO FARFARA'},
 {'EUROPEANFIELDELM', 'ULMUS MINOR'},
 {'DI TAO HUA', 'URENA LOBATA', 'XIAO FAN TIAN HUA'},
 {'SHINYBLUEBERRY', 'VACCINIUM MYRSINITES'},
 {'CRAMPBARK', 'GUELDER ROSE', 'VIBURNUM OPULUS'},
 {'FAVABEAN', 'VICIA FABA'},
 {'CHASTEBERRY', 'CHASTETREE', 'VITEX', 'VITEX AGNUS'},
 {'FOX GRAPE', 'MUSCADINE', 'MUSCADINE GRAPE', 'VITIS ROTUNDIFOLIA'},
 {'COMMON GRAPEVINE',
  'EUROPEAN GRAPE',
  'GRAPE',
  'GRAPEVINE',
  'VITIS VINIFERA'},
 {'ADAMSNEEDLE',
  'BEARGRASS',
  'NEEDLEPALM',
  'SPOONLEAF YUCCA',
  'YUCCA',
  'YUCCA FILAMENTOSA'},
 {'HERCULESCLUB',
  'PEPPERBARK',
  'SOUTHERN PRICKLYASH',
  'WEST INDIAN YELLOWWOOD',
  'ZANTHOXYLUM CLAVA'},
 {'SMILAX PSEUDOCHINA'},
 {'HARUNGANA MADAGASCARIENSIS'},
 {'QUERCUS LOBATA'},
 {'JATROPHA CURCAS'},
 {'SOLANUM ACULEASTRUM'},
 {'PTERIDIUM AQUILINUM'},
 {'ERYNGIUM FOETIDUM'},
 {'SALVIA MILTIORRHIZA'},
 {'ILEX OPACA'},
 {'COLLINSIA PARVIFLORA'},
 {'LENS CULINARIS'},
 {'CARPINUS CAROLINIANA'},
 {'ANCHUSA OFFICINALIS'},
 {'BACTRIS MAJOR'},
 {'SOLIDAGO SIMPLEX'},
 {'RUBUS CANADENSIS'},
 {'DAPHNE SERICEA'},
 {'ANGELICA PINNATA'},
 {'SALIX BABYLONICA'},
 {'HEUCHERA CYLINDRICA'},
 {'CLINOPODIUM NEPETA'},
 {'TRIFOLIUM PRATENSE'},
 {'CASTANEA PUMILA'},
 {'ARISTOLOCHIA SERICEA'},
 {'FUCUS DISTICHUS'},
 {'PIRIQUETA RACEMOSA'},
 {'AFROLICANIA ELAEOSPERMA'},
 {'DIPLOTAXIS ERUCOIDES'},
 {'HYLOTELEPHIUM TELEPHIUM'},
 {'SMILAX AURICULATA'},
 {'SALIX PYRIFOLIA'},
 {'HELMINTHOTHECA ECHIOIDES'},
 {'WATSONIA DENSIFLORA'},
 {'LYCIUM PALLIDUM'},
 {'PLUCHEA INDICA'},
 {'QUERCUS CERRIS'},
 {'SOLANUM AMERICANUM'},
 {'AGELAEA PENTAGYNA'},
 {'ASPHODELINE LUTEA'},
 {'FAGUS GRANDIFOLIA'},
 {'SMILAX GLABRA'},
 {'CEPHALANTHUS OCCIDENTALIS'},
 {'LACHNANTHES CAROLINIANA'},
 {'PISTACIA TEREBINTHUS'},
 {'SMILAX BINCHUANENSIS'},
 {'DAPHNE LAUREOLA'},
 {'SCHOENOPLECTUS TABERNAEMONTANI'},
 {'SMILAX LAURIFOLIA'},
 {'ANDROPOGON GLOMERATUS'},
 {'QUERCUS MARILANDICA'},
 {'LIRIODENDRON TULIPIFERA'},
 {'SCHINUS TEREBINTHIFOLIA'},
 {'BOLBOSCHOENUS FLUVIATILIS'},
 {'EUPHORBIA LACEI'},
 {'ASCLEPIAS STELLIFERA'},
 {'THUNBERGIA LAURIFOLIA'},
 {'HIBISCUS MOSCHEUTOS'},
 {'ECBALLIUM ELATERIUM'},
 {'ILEX MUCRONATA'},
 {'SAUSSUREA INVOLUCRATA'},
 {'RHUS COPALLINUM'},
 {'SWERTIA PSEUDOCHINENSIS'},
 {'NICOTIANA GLAUCA'},
 {'DACTYLORHIZA INCARNATA'},
 {'AFROHYBANTHUS ENNEASPERMUS'},
 {'TEPHROSIA VIRGINIANA'},
 {'HYPERICUM TRIQUETRIFOLIUM'},
 {'VICIA SATIVA'},
 {'PALIURUS SPINACHRISTI'},
 {'ERICA MULTIFLORA'},
 {'EUPHORBIA ANTISYPHILITICA'},
 {'SPARTIUM JUNCEUM'},
 {'CLUSIA FLAVA'},
 {'ANEMOPSIS CALIFORNICA'},
 {'BAUHINIA LONGIFOLIA'},
 {'CITRULLUS ECIRRHOSUS'},
 {'ILEX VOMITORIA'},
 {'DIOSCOREA PRAEHENSILIS'},
 {'CYANTHILLIUM CINEREUM'},
 {'URARIA CRINITA'},
 {'SENNA ITALICA'},
 {'ULMUS AMERICANA'},
 {'HYPERICUM GENTIANOIDES'},
 {'MAMMEA AMERICANA'},
 {'OENANTHE AQUATICA'},
 {'QUERCUS NIGRA'},
 {'ALOCASIA MACRORRHIZOS'},
 {'DITRYSINIA FRUTICOSA'},
 {'EQUISETUM ARVENSE'},
 {'TABERNAEMONTANA DIVARICATA'},
 {'ATRIPLEX NUMMULARIA'},
 {'AFRAMOMUM ANGUSTIFOLIUM'},
 {'PERSICARIA PUNCTATA'},
 {'CHRYSOJASMINUM FRUTICANS'},
 {'POLYGALA AMARA'},
 {'HYGROPHILA COSTATA'},
 {'SCOLYMUS HISPANICUS'},
 {'LIMNOPHYTON OBTUSIFOLIUM'},
 {'GLAUCIUM FLAVUM'},
 {'CLITORIA MARIANA'},
 {'THONNINGIA SANGUINEA'},
 {'ILEX CRENATA'},
 {'MORUS RUBRA'},
 {'PIPER SARMENTOSUM'},
 {'HIPPOPHAE SALICIFOLIA'},
 {'GERANIUM WILFORDII'},
 {'COCCINIA HIRTELLA'},
 {'INDIGOFERA HIRSUTA'},
 {'OXALIS ACETOSELLA'},
 {'CROTALARIA PALLIDA'},
 {'CENTRANTHUS RUBER'},
 {'GLADIOLUS DALENII'},
 {'NUPHAR LUTEA'},
 {'EUCALYPTUS ODORATA'},
 {'AESCULUS PAVIA'},
 {'CUPHEA CARTHAGENENSIS'},
 {'LACTUCA INDICA'},
 {'IRIS VIRGINICA'},
 {'SILENE LATIFOLIA'},
 {'FRAXINUS AMERICANA'},
 {'PICEA ABIES'},
 {'SCROPHULARIA UMBROSA'},
 {'ARTEMISIA HERBAALBA'},
 {'DELONIX REGIA'},
 {'TRIPSACUM DACTYLOIDES'},
 {'DESMODIUM GLUTINOSUM'},
 {'SALVIA VERBENACA'},
 {'ZANTHOXYLUM ARMATUM'},
 {'ACER PICTUM'},
 {'STYELA CLAVA'},
 {'CROTALARIA JUNCEA'},
 {'SENECIO FISTULOSUS'},
 {'SALIX NIGRA'},
 {'HELICHRYSUM GYMNOCEPHALUM'},
 {'EUPATORIUM FORTUNEI'},
 {'DROSERA INTERMEDIA'},
 {'CENTAUREA BENEDICTA'},
 {'RHEUM ACUMINATUM'},
 {'FICUS SUR'},
 {'CORYDALIS BUNGEANA'},
 {'QUERCUS FALCATA'},
 {'TAMARIX CHINENSIS'},
 {'SWERTIA LEDUCII'},
 {'COMBRETUM MOLLE'},
 {'AMORPHA FRUTICOSA'},
 {'VERBASCUM SINUATUM'},
 {'CELTIS GOMPHOPHYLLA'},
 {'QUERCUS MACROCARPA'},
 {'EUPATORIUM CAPILLIFOLIUM'},
 {'PRUNUS CORNUTA'},
 {'THYMBRA CAPITATA'},
 {'MIKANIA BANISTERIAE'},
 {'CELTIS LAEVIGATA'},
 {'ASTRAGALUS HUMISTRATUS'},
 {'ALBATRELLUS CONFLUENS'},
 {'PRUNUS ANGUSTIFOLIA'},
 {'RUMEX VENOSUS'},
 {'DIGITALIS FERRUGINEA'},
 {'CENTROSEMA VIRGINIANUM'},
 {'PARTHENOCISSUS QUINQUEFOLIA'},
 {'CLEMATIS VILLOSA'},
 {'LEPIDIUM VIRGINICUM'},
 {'ERYTHRINA LYSISTEMON'},
 {'EUGENIA BIFLORA'},
 {'CROTON STELLATOPILOSUS'},
 {'IPOMOEA PANDURATA'},
 {'CARCHARHINUS LEUCAS'},
 {'IMPATIENS PARVIFLORA'},
 {'TRIFOLIUM REPENS'},
 {'PAPAVER SOMNIFERUM'},
 {'SALVIA TOMENTOSA'},
 {'RUBUS LACINIATUS'},
 {'PSEUDARTHRIA HOOKERI'},
 {'MARKHAMIA LUTEA'},
 {'PSEUDOGNAPHALIUM STRAMINEUM'},
 {'CEDRUS LIBANI'},
 {'ANTHYLLIS VULNERARIA'},
 {'ASCLEPIAS CURASSAVICA'},
 {'CRATAEGUS SONGARICA'},
 {'QUERCUS VIRGINIANA'},
 {'PSORALEA PINNATA'},
 {'PHYSALIS VIRGINIANA'},
 {'VITEX DONIANA'},
 {'ROSA DAMASCENA'},
 {'DIGITARIA INSULARIS'},
 {'SMYRNIUM OLUSATRUM'},
 {'DRYOBALANOPS AROMATICA'},
 {'RIVINA HUMILIS'},
 {'ERECHTITES HIERACIFOLIUS'},
 {'GYMNEMA LATIFOLIUM'},
 {'SONCHUS OLERACEUS'},
 {'SAURURUS CERNUUS'},
 {'PINUS KESIYA'},
 {'RANUNCULUS ACRIS'},
 {'RUBUS ALLEGHENIENSIS'},
 {'PASPALUM NOTATUM'},
 {'KNAUTIA ARVENSIS'},
 {'ALCEA ROSEA'},
 {'CECROPIA PELTATA'},
 {'DIANTHUS CRENATUS'},
 {'MANDRAGORA OFFICINARUM'},
 {'CRATAEGUS GRACILIOR'},
 {'CENTAURIUM PULCHELLUM'},
 {'RHYNCHOSTYLIS RETUSA'},
 {'MAERUA CRASSIFOLIA'},
 {'STACHYS MEXICANA'},
 {'ALECTRA SESSILIFLORA'},
 {'CLARKIA PURPUREA'},
 {'IPOMOEA DUMOSA'},
 {'CLINACANTHUS NUTANS'},
 {'CORDIA DENTATA'},
 {'ACACIA SALIGNA'},
 {'RUBUS PARVIFOLIUS'},
 {'SMILAX GLAUCA'},
 {'FRAXINUS QUADRANGULATA'},
 {'COLEUS',
  'COLEUS AMBOINICUS WHOLE',
  'COLEUS AROMATICUS WHOLE',
  'COLEUS CARNOSUS WHOLE',
  'COLEUS CRASSIFOLIUS WHOLE',
  'COLEUS SUBFRUTECTOSUS WHOLE',
  'COLEUS SUBORBICULARIS WHOLE',
  'COLEUS SUGANDA WHOLE',
  'COLEUS VAALAE WHOLE',
  'CUBAN OREGANO WHOLE',
  'INDIAN BORAGE HOC',
  'INDIAN BORAGE WHOLE',
  'INDIAN THYME WHOLE',
  'MAJANA AMBOINICA WHOLE',
  'MAJANA CARNOSA WHOLE',
  'MAJANA SUGANDA WHOLE',
  'MEXICAN MINT WHOLE',
  'MEXICAN THYME WHOLE',
  'OCIMUM VAALAE WHOLE',
  'PLECTRANTHUS AMBOINICUS',
  'PLECTRANTHUS AMBOINICUS LOUR SPRENG',
  'PLECTRANTHUS AMBOINICUS WHOLE',
  'VICKS PLANT WHOLE'},
 {'ARUM ITALICUM'},
 {'EUCLEA RACEMOSA'},
 {'ARCTOSTAPHYLOS NEVADENSIS'},
 {'CARTHAMUS LANATUS'},
 {'AMPELOCISSUS LATIFOLIA'},
 {'CALLICARPA AMERICANA'},
 {'PICEA MARIANA'},
 {'LUPINUS PERENNIS'},
 {'ASARUM CANADENSE'},
 {'ADIANTUM LATIFOLIUM'},
 {'WARBURGIA UGANDENSIS'},
 {'SESELI LIBANOTIS'},
 {'PARONYCHIA ARGENTEA'},
 {'PONTEDERIA CORDATA'},
 {'SPERMACOCE VERTICILLATA'},
 {'ALCEA SETOSA'},
 {'RICINUS COMMUNIS'},
 {'PELTANDRA VIRGINICA'},
 {'CARYA ALBA'},
 {'CASTILLEJA MINIATA'},
 {'CORNUS FLORIDA'},
 {'QUERCUS STELLATA'},
 {'DIANTHUS CARTHUSIANORUM'},
 {'TEUCRIUM CRETICUM'},
 {'TILIA AMERICANA'},
 {'ERYTHRINA CRISTAGALLI'},
 {'QUERCUS CHRYSOLEPIS'},
 {'CROTON DRACONOIDES'},
 {'MERTESIA VIRGINICA'},
 {'ARENARIA LANUGINOSA'},
 {'CIRSIUM ERIOPHORUM'},
 {'MEUM ATHAMANTICUM'},
 {'PINUS ECHINATA'},
 {'ACHILLEA NOBILIS'},
 {'JACOBAEA MARITIMA'},
 {'BAPTISIA ALBA'},
 {'COMMELINA DIFFUSA'},
 {'TODDALIA ASIATICA'},
 {'LUDWIGIA ERECTA'},
 {'ACACIA DEALBATA'},
 {'EUPHORBIA OFFICINARUM'},
 {'RUBUS RIGIDUS'},
 {'FERULA SINKIANGENSIS'},
 {'IPOMOEA WOLCOTTIANA'},
 {'CNIDOSCOLUS URENS'},
 {'ERIGERON STRIGOSUS'},
 {'ALLIUM PORRUM'},
 {'MIKANIA SCANDENS'},
 {'DELPHINIUM GRANDIFLORUM'},
 {'ORIGANUM ONITES'},
 {'DAPHNE GNIDIUM'},
 {'SABAL MINOR'},
 {'OPUNTIA HUMIFUSA'},
 {'ZANTHOXYLUM OVALIFOLIUM'},
 {'AMOMUM AROMATICUM'},
 {'OXYRIA DIGYNA'},
 {'LONICERA HYPOGLAUCA'},
 {'ALOYSIA TRIPHYLLA'},
 {'CYMBOPOGON SCHOENANTHUS'},
 {'CAPSELLA BURSAPASTORIS'},
 {'XANTHIUM STRUMARIUM'},
 {'LUDWIGIA PEPLOIDES'},
 {'JUNCUS TORREYI'},
 {'SCHIZACHYRIUM SCOPARIUM'},
 {'THAPSIA GARGANICA'},
 {'GREWIA VILLOSA'},
 {'CAMPSIS RADICANS'},
 {'LIMONIUM NARBONENSE'},
 {'EICHHORNIA CRASSIPES'},
 {'MONESES UNIFLORA'},
 {'LEPIDIUM DRABA'},
 {'NEPETA HINDOSTANA'},
 {'PLANTAGO ARISTATA'},
 {'SAMBUCUS EBULUS'},
 {'SPHYRNA LEWINI'},
 {'ASCLEPIAS PERENNIS'},
 {'PLECTRANTHUS ESCULENTUS'},
 {'CYCLAMEN HEDERIFOLIUM'},
 {'SALVIA ROSMARINUS'},
 {'BRASSICA BRASSICA OLERACEA'},
 {'PYROSTEGIA VENUSTA'},
 {'BOLETUS EDULIS'},
 {'DIPSACUS FULLONUM'},
 {'PALISOTA HIRSUTA'},
 {'RUBUS CUNEIFOLIUS'},
 {'PLATANTHERA PSYCODES'},
 {'BAUHINIA DIVARICATA'},
 {'ERYTHRINA HERBACEA'},
 {'ASTRAGALUS MONSPESSULANUS'},
 {'QUERCUS GAMBELII'},
 {'SESAMUM RADIATUM'},
 {'TYPHA DOMINGENSIS'},
 {'ZALUZIANSKYA CAPENSIS'},
 {'KALANCHOE CRENATA'},
 {'GARDENIA THUNBERGIA'},
 {'ASCLEPIAS INCARNATA'},
 {'ARTEMISIA ARBORESCENS'},
 {'DAPHNE OLEOIDES'},
 {'MOMORDICA COCHINCHINENSIS'},
 {'MITRACARPUS HIRTUS'},
 {'COLLOMIA LINEARIS'},
 {'GALIUM TRIFLORUM'},
 {'LESSERTIA TOMENTOSA'},
 {'VACCINIUM ANGUSTIFOLIUM'},
 {'ALBIZIA CORIARIA'},
 {'FRAXINUS ANGUSTIFOLIA'},
 {'COMMELINA BENGHALENSIS'},
 {'TEUCRIUM CHAMAEDRYS'},
 {'BRASSICA NIGRA'},
 {'ORBEXILUM PEDUNCULATUM'},
 {'PILOBLEPHIS RIGIDA'},
 {'CERCIS CANADENSIS'},
 {'SALVIA MACROSIPHON'},
 {'WISTERIA SINENSIS'},
 {'ERIGERON FLORIBUNDUS'},
 {'FERULA COMMUNIS'},
 {'HYPERICUM HYPERICOIDES'},
 {'CERINTHE MAJOR'},
 {'TYPHA LATIFOLIA'},
 {'MAESA LANCEOLATA'},
 {'ARUNDO DONAX'},
 {'ENTEROLOBIUM CYCLOCARPUM'},
 {'CLINOPODIUM BOLIVIANUM'},
 {'MIRABILIS JALAPA'},
 {'THELYPTERIS KUNTHII'},
 {'RUBUS FLAGELLARIS'},
 {'CROSSOPTERYX FEBRIFUGA'},
 {'KADSURA JAPONICA'},
 {'STADMANIA OPPOSITIFOLIA'},
 {'SESBANIA SESBAN'},
 {'STACHYS BULLATA'},
 {'ASPARAGUS SETACEUS'},
 {'GENTIANA PNEUMONANTHE'},
 {'MACLURA TINCTORIA'},
 {'HALOXYLON AMMODENDRON'},
 {'CORYLUS AMERICANA'},
 {'VACCINIUM PALLIDUM'},
 {'VINCA MAJOR'},
 {'NASTURTIUM OFFICINALE'},
 {'GRINDELIA CILIATA'},
 {'VERONICA CHAMAEDRYS'},
 {'GALIUM UNIFLORUM'},
 {'CHRYSOPSIS MARIANA'},
 {'PSEUDOGNAPHALIUM VISCOSUM'},
 {'CLINOPODIUM POLYCEPHALUM'},
 {'ZIZANIA AQUATICA'},
 {'ARMILLARIA GALLICA'},
 {'PERIPLOCA LAEVIGATA'},
 {'ALLIUM MACROSTEMON'},
 {'ACALYPHA FRUTICOSA'},
 {'MELILOTUS ALBUS'},
 {'TORMINALIS GLABERRIMA'},
 {'ANEMONE HEPATICA'},
 {'LONICERA PERICLYMENUM'},
 {'CRATAEGUS AZAROLUS'},
 {'QUERCUS ILEX'},
 {'FRANGULA CAROLINIANA'},
 {'ASTRAGALUS PROPINQUUS'},
 {'TEUCRIUM BOTRYS'},
 {'HYPERICUM REVOLUTUM'},
 {'STERCULIA URENS'},
 {'SIDA SPINOSA'},
 {'DIPLOTAXIS TENUIFOLIA'},
 {'ERYTHRINA ABYSSINICA'},
 {'ARISTOLOCHIA FIMBRIATA'},
 {'NEPETA TENUIFOLIA'},
 {'HYPERICUM PUNCTATUM'},
 {'ARISTOLOCHIA RUGOSA'},
 {'THUJA PLICATA'},
 {'TRIGONELLA CORNICULATA'},
 {'SMILAX ROTUNDIFOLIA'},
 {'ERIOGONUM ALATUM'},
 {'NEPHROLEPIS CORDIFOLIA'},
 {'RUDBECKIA HIRTA'},
 {'FOMITOPSIS PINICOLA'},
 {'FICUS SAUSSUREANA'},
 {'CLADIUM MARISCUS'},
 {'ERODIUM MALACOIDES'},
 {'CARYA ILLINOINENSIS'},
 {'VITIS AESTIVALIS'},
 {'TABERNAEMONTANA AURANTIACA'},
 {'SALVIA MICROPHYLLA'},
 {'DICHORISANDRA HEXANDRA'},
 {'ANDROPOGON VIRGINICUS'},
 {'AMBROSIA ARTEMISIIFOLIA'},
 {'CANTINOA AMERICANA'},
 {'GENTIANA OLIVIERI'},
 {'STACHYS TENUIFOLIA'},
 {'EUPATORIUM LINDLEYANUM'},
 {'MAGNOLIA TRIPETALA'},
 {'NIPHIDIUM CRASSIFOLIUM'},
 {'SALIX TRIANDRA'},
 {'LECHEA MINOR'},
 {'BLUMEA LACERA'},
 {'RHEXIA VIRGINICA'},
 {'SPHAGNUM SQUARROSUM'},
 {'PYRUS NIVALIS'},
 {'PERSICARIA MACULOSA'},
 {'AMOMUM ACULEATUM'},
 {'THYMUS PRAECOX'},
 {'SOLANUM CAROLINENSE'},
 {'ZANTHOXYLUM SIMULANS'},
 {'SALIX LUCIDA'},
 {'ENDOTROPIS ALNIFOLIA'},
 {'BIDENS BIPINNATA'},
 {'ACHILLEA AGERATUM'},
 {'KHAYA ANTHOTHECA'},
 {'EUPATORIUM JAPONICUM'},
 {'PISTIA STRATIOTES'},
 {'RUBUS TRIVIALIS'},
 {'PERSICARIA HYDROPIPEROIDES'},
 {'AMANITA RUBESCENS'},
 {'SOLANUM NIGRUM'},
 {'DRIMA MARITIMA'},
 {'POLIOMINTHA INCANA'},
 {'LINARIA VULGARIS'},
 {'CASTANEA MOLLISSIMA'},
 {'SOLANUM LINNAEANUM'},
 {'BOSWELFIA SERRATA'},
 {'OLIVE LEAF'}]

len(sorted([len(x) for x in equivalence_group])) - 220
# Out:
# 503
